# %% [markdown]
# # Import Dataset

# %%
import pandas as pd

df = pd.read_csv("../Database/sales_data_sample.csv", sep=",", encoding='Latin-1')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %% [markdown]
# # Examine Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# # Split Dataset

# %%
# customers tablosu
customers = df[['CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME']].drop_duplicates()
customers['id'] = range(1, len(customers) + 1)

# products tablosu
products = df[['PRODUCTCODE', 'PRODUCTLINE', 'MSRP']].drop_duplicates()

# orders tablosu
orders = df[['ORDERNUMBER', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID', 'DEALSIZE', 'CUSTOMERNAME']].drop_duplicates()
orders = orders.merge(customers[['CUSTOMERNAME', 'id']], on='CUSTOMERNAME').drop(columns='CUSTOMERNAME')
orders = orders.rename(columns={'id': 'customer_id'})

# order_items tablosu
order_items = df[['ORDERNUMBER', 'PRODUCTCODE', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER', 'SALES']]

# %%
customers.head()
# Out:
#                CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# 0         Land of Toys Inc.        2125557818        897 Long Airport Avenue
# 1        Reims Collectables        26.47.1555             59 rue de l'Abbaye
# 2           Lyon Souveniers  +33 1 46 62 7555  27 rue du Colonel Pierre Avia
# 3         Toys4GrownUps.com        6265557265             78934 Hillside Dr.
# 4  Corporate Gift Ideas Co.        6505551386                7734 Strong St.
#
#   ADDRESSLINE2           CITY STATE POSTALCODE COUNTRY TERRITORY  \
# 0          NaN            NYC    NY      10022     USA       NaN
# 1          NaN          Reims   NaN      51100  France      EMEA
# 2          NaN          Paris   NaN      75508  France      EMEA
# 3          NaN       Pasadena    CA      90003     USA       NaN
# 4          NaN  San Francisco    CA        NaN     USA       NaN
#
#   CONTACTLASTNAME CONTACTFIRSTNAME  id
# 0              Yu             Kwai   1
# ...

# %%
products.head()
# Out:
#     PRODUCTCODE   PRODUCTLINE  MSRP
# 0      S10_1678   Motorcycles    95
# 26     S10_1949  Classic Cars   214
# 54     S10_2016   Motorcycles   118
# 80     S10_4698   Motorcycles   193
# 106    S10_4757  Classic Cars   136

# %%
orders.head()
# Out:
#    ORDERNUMBER        ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID DEALSIZE  \
# 0        10107   2/24/2003 0:00  Shipped       1         2     2003    Small
# 1        10121    5/7/2003 0:00  Shipped       2         5     2003    Small
# 2        10134    7/1/2003 0:00  Shipped       3         7     2003   Medium
# 3        10145   8/25/2003 0:00  Shipped       3         8     2003   Medium
# 4        10159  10/10/2003 0:00  Shipped       4        10     2003   Medium
#
#    customer_id
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5

# %%
order_items.head()
# Out:
#    ORDERNUMBER PRODUCTCODE  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# 0        10107    S10_1678               30      95.70                2
# 1        10121    S10_1678               34      81.35                5
# 2        10134    S10_1678               41      94.74                2
# 3        10145    S10_1678               45      83.26                6
# 4        10159    S10_1678               49     100.00               14
#
#      SALES
# 0  2871.00
# 1  2765.90
# 2  3884.34
# 3  3746.70
# 4  5205.27

# %%
customers.columns.append(products.columns.append(orders.columns.append(order_items.columns)))
# Out:
# Index(['CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY',
#        'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME',
#        'CONTACTFIRSTNAME', 'id', 'PRODUCTCODE', 'PRODUCTLINE', 'MSRP',
#        'ORDERNUMBER', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'DEALSIZE', 'customer_id', 'ORDERNUMBER', 'PRODUCTCODE',
#        'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER', 'SALES'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# # Export Tables

# %%
# Verileri CSV dosyalarına kaydetme
customers.to_csv('../Database/customers.csv', index=False)
products.to_csv('../Database/products.csv', index=False)
orders.to_csv('../Database/orders.csv', index=False)
order_items.to_csv('../Database/order_items.csv', index=False)
