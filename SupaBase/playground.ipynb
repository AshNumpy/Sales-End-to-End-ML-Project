# %%
# Load environment variables
from dotenv import load_dotenv
load_dotenv('.env')
# Out:
# True

# %%
# Initialize Supabase
import os
from supabase import create_client, Client

url: str = os.environ.get("SUPABASE_URL")
key: str = os.environ.get("SUPABASE_KEY")
supabase: Client = create_client(url, key)

# %%
response = supabase.from_("Customers").select("*").execute()

# %%
json_response = response.data
json_response[:1]
# Out:
# [{'ID': 1,
#   'CUSTOMERNAME': 'Land of Toys Inc.',
#   'PHONE': '2125557818',
#   'ADDRESSLINE1': '897 Long Airport Avenue',
#   'ADDRESSLINE2': 'Bilinmiyor',
#   'CITY': 'NYC',
#   'STATE': 'NY',
#   'POSTALCODE': '10022',
#   'COUNTRY': 'USA',
#   'TERRITORY': 'Bilinmiyor',
#   'CONTACTLASTNAME': 'Yu',
#   'CONTACTFIRSTNAME': 'Kwai',
#   'SEGMENT': 111}]

# %%
import pandas as pd 

df = pd.DataFrame(json_response)
df
# Out:
#     ID                        CUSTOMERNAME         PHONE  \
# 0    1                   Land of Toys Inc.    2125557818
# 1    2                  Reims Collectables      26471555
# 2    3                     Lyon Souveniers   33146627555
# 3    4                   Toys4GrownUps.com    6265557265
# 4    5            Corporate Gift Ideas Co.    6505551386
# ..  ..                                 ...           ...
# 87  88        Australian Collectables, Ltd   61938446555
# 88  89                    Gift Ideas Corp.    2035554407
# 89  90  Bavarian Collectables Imports, Co.  498961089555
# 90  91                        Royale Belge    7123672555
# 91  92             Auto-Moto Classics Inc.    6175558428
#
#                      ADDRESSLINE1 ADDRESSLINE2           CITY       STATE  \
# 0         897 Long Airport Avenue   Bilinmiyor            NYC          NY
# 1              59 rue de l'Abbaye   Bilinmiyor          Reims  Bilinmiyor
# 2   27 rue du Colonel Pierre Avia   Bilinmiyor          Paris  Bilinmiyor
# 3              78934 Hillside Dr.   Bilinmiyor       Pasadena          CA
# 4                 7734 Strong St.   Bilinmiyor  San Francisco          CA
# ..                            ...          ...            ...         ...
# 87                 7 Allen Street   Bilinmiyor   Glen Waverly    Victoria
# 88               2440 Pompton St.   Bilinmiyor       Glendale          CT
# 89                   Hansastr. 15   Bilinmiyor         Munich  Bilinmiyor
# 90           Boulevard Tirou, 255   Bilinmiyor      Charleroi  Bilinmiyor
# 91              16780 Pompton St.   Bilinmiyor     Brickhaven          MA
#
#     POSTALCODE    COUNTRY   TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# 0        10022        USA  Bilinmiyor              Yu             Kwai
# 1        51100     France        EMEA         Henriot             Paul
# 2        75508     France        EMEA        Da Cunha           Daniel
# 3        90003        USA  Bilinmiyor           Young            Julie
# 4   Bilinmiyor        USA  Bilinmiyor           Brown            Julie
# ..         ...        ...         ...             ...              ...
# 87        3150  Australia        APAC         Connery             Sean
# 88       97561        USA  Bilinmiyor           Lewis              Dan
# 89       80686    Germany        EMEA     Donnermeyer          Michael
# 90      B-6000    Belgium        EMEA        Cartrain          Pascale
# 91       58339        USA  Bilinmiyor          Taylor           Leslie
#
#     SEGMENT
# 0       111
# 1       121
# 2       111
# 3       111
# 4       222
# ..      ...
# 87      111
# 88      111
# 89      111
# 90      111
# 91      111
#
# [92 rows x 13 columns]
